# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
filename = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df = pd.read_csv(filename, names = headers)

# %%
df['fuel-type'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
dummy_variable1 = pd.get_dummies(df['fuel-type'])

# %%
dummy_variable1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable1.rename(columns={'diesel':'fule-type-diesel','gas':'fuel-type-gas'},inplace = True)

# %%
dummy_variable1
# Out:
#      fule-type-diesel  fuel-type-gas
# 0                   0              1
# 1                   0              1
# 2                   0              1
# 3                   0              1
# 4                   0              1
# ..                ...            ...
# 200                 0              1
# 201                 0              1
# 202                 0              1
# 203                 1              0
# 204                 0              1
#
# [205 rows x 2 columns]

# %%
df = pd.concat([df,dummy_variable1],axis =1)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  \
# 0    3.47    2.68                9.0         111     5000       21
# 1    3.47    2.68                9.0         111     5000       21
# 2    2.68    3.47                9.0         154     5000       19
# 3    3.19    3.40               10.0         102     5500       24
# 4    3.19    3.40                8.0         115     5500       18
# ..    ...     ...                ...         ...      ...      ...
# 200  3.78    3.15                9.5         114     5400       23
# 201  3.78    3.15                8.7         160     5300       19
# 202  3.58    2.87                8.8         134     5500       18
# 203  3.01    3.40               23.0         106     4800       26
# 204  3.78    3.15                9.5         114     5400       19
#
#      highway-mpg  price fule-type-diesel fuel-type-gas
# 0             27  13495                0             1
# 1             27  16500                0             1
# 2             26  16500                0             1
# 3             30  13950                0             1
# 4             22  17450                0             1
# ..           ...    ...              ...           ...
# 200           28  16845                0             1
# 201           25  19045                0             1
# 202           23  21485                0             1
# 203           27  22470                1             0
# 204           25  22625                0             1
#
# [205 rows x 28 columns]

# %%
df.drop('fuel-type',axis = 1,inplace = True)
df
# Out:
#      symboling normalized-losses         make aspiration num-of-doors  \
# 0            3                 ?  alfa-romero        std          two
# 1            3                 ?  alfa-romero        std          two
# 2            1                 ?  alfa-romero        std          two
# 3            2               164         audi        std         four
# 4            2               164         audi        std         four
# ..         ...               ...          ...        ...          ...
# 200         -1                95        volvo        std         four
# 201         -1                95        volvo      turbo         four
# 202         -1                95        volvo        std         four
# 203         -1                95        volvo      turbo         four
# 204         -1                95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  bore  \
# 0    convertible          rwd           front        88.6   168.8  ...  3.47
# 1    convertible          rwd           front        88.6   168.8  ...  3.47
# 2      hatchback          rwd           front        94.5   171.2  ...  2.68
# 3          sedan          fwd           front        99.8   176.6  ...  3.19
# 4          sedan          4wd           front        99.4   176.6  ...  3.19
# ..           ...          ...             ...         ...     ...  ...   ...
# 200        sedan          rwd           front       109.1   188.8  ...  3.78
# 201        sedan          rwd           front       109.1   188.8  ...  3.78
# 202        sedan          rwd           front       109.1   188.8  ...  3.58
# 203        sedan          rwd           front       109.1   188.8  ...  3.01
# 204        sedan          rwd           front       109.1   188.8  ...  3.78
#
#      stroke  compression-ratio horsepower peak-rpm  city-mpg highway-mpg  \
# 0      2.68                9.0        111     5000        21          27
# 1      2.68                9.0        111     5000        21          27
# 2      3.47                9.0        154     5000        19          26
# 3      3.40               10.0        102     5500        24          30
# 4      3.40                8.0        115     5500        18          22
# ..      ...                ...        ...      ...       ...         ...
# 200    3.15                9.5        114     5400        23          28
# 201    3.15                8.7        160     5300        19          25
# 202    2.87                8.8        134     5500        18          23
# 203    3.40               23.0        106     4800        26          27
# 204    3.15                9.5        114     5400        19          25
#
#      price fule-type-diesel  fuel-type-gas
# 0    13495                0              1
# 1    16500                0              1
# 2    16500                0              1
# 3    13950                0              1
# 4    17450                0              1
# ..     ...              ...            ...
# 200  16845                0              1
# 201  19045                0              1
# 202  21485                0              1
# 203  22470                1              0
# 204  22625                0              1
#
# [205 rows x 27 columns]

# %%
df.reset_index()
# Out:
#      index  symboling normalized-losses         make aspiration num-of-doors  \
# 0        0          3                 ?  alfa-romero        std          two
# 1        1          3                 ?  alfa-romero        std          two
# 2        2          1                 ?  alfa-romero        std          two
# 3        3          2               164         audi        std         four
# 4        4          2               164         audi        std         four
# ..     ...        ...               ...          ...        ...          ...
# 200    200         -1                95        volvo        std         four
# 201    201         -1                95        volvo      turbo         four
# 202    202         -1                95        volvo        std         four
# 203    203         -1                95        volvo      turbo         four
# 204    204         -1                95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  ...  bore  stroke  \
# 0    convertible          rwd           front        88.6  ...  3.47    2.68
# 1    convertible          rwd           front        88.6  ...  3.47    2.68
# 2      hatchback          rwd           front        94.5  ...  2.68    3.47
# 3          sedan          fwd           front        99.8  ...  3.19    3.40
# 4          sedan          4wd           front        99.4  ...  3.19    3.40
# ..           ...          ...             ...         ...  ...   ...     ...
# 200        sedan          rwd           front       109.1  ...  3.78    3.15
# 201        sedan          rwd           front       109.1  ...  3.78    3.15
# 202        sedan          rwd           front       109.1  ...  3.58    2.87
# 203        sedan          rwd           front       109.1  ...  3.01    3.40
# 204        sedan          rwd           front       109.1  ...  3.78    3.15
#
#      compression-ratio  horsepower peak-rpm city-mpg  highway-mpg  price  \
# 0                  9.0         111     5000       21           27  13495
# 1                  9.0         111     5000       21           27  16500
# 2                  9.0         154     5000       19           26  16500
# 3                 10.0         102     5500       24           30  13950
# 4                  8.0         115     5500       18           22  17450
# ..                 ...         ...      ...      ...          ...    ...
# 200                9.5         114     5400       23           28  16845
# 201                8.7         160     5300       19           25  19045
# 202                8.8         134     5500       18           23  21485
# 203               23.0         106     4800       26           27  22470
# 204                9.5         114     5400       19           25  22625
#
#     fule-type-diesel fuel-type-gas
# 0                  0             1
# 1                  0             1
# 2                  0             1
# 3                  0             1
# 4                  0             1
# ..               ...           ...
# 200                0             1
# 201                0             1
# 202                0             1
# 203                1             0
# 204                0             1
#
# [205 rows x 28 columns]
